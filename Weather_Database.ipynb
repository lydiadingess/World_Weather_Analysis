# %%
# Import dependencies.
import pandas as pd
import numpy as np

# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 776

# %%
# Perform an API call with the OpenWeatherMap.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Retrieve the following information from the API call:

# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | praia da vitoria
# Processing Record 5 of Set 1 | ulcinj
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | mecca
# Processing Record 9 of Set 1 | alofi
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | kedrovyy
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | yunyang
# Processing Record 14 of Set 1 | kruisfontein
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | ust-kuyga
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | necochea
# Processing Record 20 of Set 1 | bridlington
# Processing Record 21 of Set 1 | bria
# Processing Record 22 of Set 1 | coihaique
# Processing Record 23 of Set 1 | touros
# Processing Record 24 of Set 1 | luanda
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | kargasok
# Processing Record 28 of Set 1 | vangaindrano
# Processing Record 29 of Set 1 | linxia
# Processing Record 30 of Set 1 | saskylakh
# Processing Record 31 of Set 1 | tuatapere
# Processing Record 32 of Set 1 | zhenlai
# Processing Record 33 of Set 1 | markova
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | ahipara
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | cherskiy
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | dong xoai
# Processing Record 44 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | esperance
# Processing Record 2 of Set 2 | makakilo city
# Processing Record 3 of Set 2 | college
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | kamaishi
# Processing Record 6 of Set 2 | clinton
# Processing Record 7 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 2 | lompoc
# Processing Record 9 of Set 2 | airai
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | cabo san lucas
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | qeshm
# Processing Record 14 of Set 2 | khandyga
# Processing Record 15 of Set 2 | paita
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | samarai
# Processing Record 19 of Set 2 | murakami
# Processing Record 20 of Set 2 | tazovskiy
# Processing Record 21 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 2 | tigil
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | auki
# Processing Record 27 of Set 2 | gorontalo
# Processing Record 28 of Set 2 | half moon bay
# Processing Record 29 of Set 2 | vila velha
# Processing Record 30 of Set 2 | severo-kurilsk
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | hendek
# Processing Record 33 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 34 of Set 2 | khorinsk
# Processing Record 35 of Set 2 | rio gallegos
# Processing Record 36 of Set 2 | kavieng
# Processing Record 37 of Set 2 | cristalina
# Processing Record 38 of Set 2 | namanyere
# Processing Record 39 of Set 2 | chilca
# Processing Record 40 of Set 2 | bestobe
# Processing Record 41 of Set 2 | korop
# Processing Record 42 of Set 2 | rocha
# Processing Record 43 of Set 2 | asfi
# Processing Record 44 of Set 2 | waverley
# Processing Record 45 of Set 2 | kyzyl-suu
# Processing Record 46 of Set 2 | tabarqah
# City not found. Skipping...
# Processing Record 47 of Set 2 | nuuk
# Processing Record 48 of Set 2 | hami
# Processing Record 49 of Set 2 | turukhansk
# Processing Record 50 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 3 | nkhata bay
# Processing Record 2 of Set 3 | san cristobal
# Processing Record 3 of Set 3 | longonjo
# Processing Record 4 of Set 3 | kaeo
# Processing Record 5 of Set 3 | yerbogachen
# Processing Record 6 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 3 | mindelo
# Processing Record 8 of Set 3 | parana
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 3 | gull lake
# Processing Record 11 of Set 3 | fonte boa
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | mbandaka
# Processing Record 14 of Set 3 | carutapera
# Processing Record 15 of Set 3 | barranca
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | qasigiannguit
# Processing Record 18 of Set 3 | kudahuvadhoo
# Processing Record 19 of Set 3 | aksu
# Processing Record 20 of Set 3 | nerchinskiy zavod
# Processing Record 21 of Set 3 | namibe
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | hobart
# Processing Record 25 of Set 3 | baturaja
# Processing Record 26 of Set 3 | teacapan
# Processing Record 27 of Set 3 | nanchang
# Processing Record 28 of Set 3 | santa fe do sul
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | hamilton
# Processing Record 31 of Set 3 | nantucket
# Processing Record 32 of Set 3 | salinopolis
# Processing Record 33 of Set 3 | beringovskiy
# Processing Record 34 of Set 3 | maracacume
# Processing Record 35 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 3 | saginaw
# Processing Record 37 of Set 3 | lata
# Processing Record 38 of Set 3 | khatassy
# Processing Record 39 of Set 3 | davidson
# Processing Record 40 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 3 | palana
# Processing Record 42 of Set 3 | adrar
# Processing Record 43 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 3 | soyo
# Processing Record 45 of Set 3 | karasjok
# Processing Record 46 of Set 3 | neiafu
# Processing Record 47 of Set 3 | qarqin
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | sembe
# Processing Record 50 of Set 3 | mujiayingzi
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | sam roi yot
# Processing Record 3 of Set 4 | victoria
# Processing Record 4 of Set 4 | tezu
# Processing Record 5 of Set 4 | beloha
# Processing Record 6 of Set 4 | buchanan
# Processing Record 7 of Set 4 | kostomuksha
# Processing Record 8 of Set 4 | murici
# Processing Record 9 of Set 4 | new norfolk
# Processing Record 10 of Set 4 | culebra
# Processing Record 11 of Set 4 | san carlos de bariloche
# Processing Record 12 of Set 4 | srandakan
# Processing Record 13 of Set 4 | barrow
# Processing Record 14 of Set 4 | charters towers
# Processing Record 15 of Set 4 | amalapuram
# Processing Record 16 of Set 4 | laguna
# Processing Record 17 of Set 4 | provideniya
# Processing Record 18 of Set 4 | sola
# Processing Record 19 of Set 4 | yulara
# Processing Record 20 of Set 4 | vardo
# Processing Record 21 of Set 4 | birin
# Processing Record 22 of Set 4 | bandarbeyla
# Processing Record 23 of Set 4 | coari
# Processing Record 24 of Set 4 | yar-sale
# Processing Record 25 of Set 4 | east london
# Processing Record 26 of Set 4 | katsuura
# Processing Record 27 of Set 4 | adre
# Processing Record 28 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 4 | castro
# Processing Record 30 of Set 4 | tiksi
# Processing Record 31 of Set 4 | alexandria
# Processing Record 32 of Set 4 | wembley
# Processing Record 33 of Set 4 | harper
# Processing Record 34 of Set 4 | rio grande
# Processing Record 35 of Set 4 | aklavik
# Processing Record 36 of Set 4 | booue
# Processing Record 37 of Set 4 | sitka
# Processing Record 38 of Set 4 | coquimbo
# Processing Record 39 of Set 4 | mitu
# Processing Record 40 of Set 4 | cartagena
# Processing Record 41 of Set 4 | rawson
# Processing Record 42 of Set 4 | sivaganga
# Processing Record 43 of Set 4 | nizhniy kuranakh
# Processing Record 44 of Set 4 | constitucion
# Processing Record 45 of Set 4 | lewisville
# Processing Record 46 of Set 4 | sebrovo
# Processing Record 47 of Set 4 | kaitangata
# Processing Record 48 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 4 | vestmannaeyjar
# Processing Record 50 of Set 4 | nikolskoye
# Processing Record 1 of Set 5 | podgornoye
# Processing Record 2 of Set 5 | emerald
# Processing Record 3 of Set 5 | mongagua
# Processing Record 4 of Set 5 | salalah
# Processing Record 5 of Set 5 | shitanjing
# Processing Record 6 of Set 5 | ribeira grande
# Processing Record 7 of Set 5 | yumen
# Processing Record 8 of Set 5 | zaysan
# Processing Record 9 of Set 5 | kalmunai
# Processing Record 10 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 11 of Set 5 | buraydah
# Processing Record 12 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 5 | comodoro rivadavia
# Processing Record 14 of Set 5 | sabha
# Processing Record 15 of Set 5 | praia
# Processing Record 16 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 5 | ukiah
# Processing Record 18 of Set 5 | haines junction
# Processing Record 19 of Set 5 | tayu
# Processing Record 20 of Set 5 | vagur
# Processing Record 21 of Set 5 | leirvik
# Processing Record 22 of Set 5 | noumea
# Processing Record 23 of Set 5 | chulym
# Processing Record 24 of Set 5 | oksfjord
# Processing Record 25 of Set 5 | mehamn
# Processing Record 26 of Set 5 | prachuap khiri khan
# Processing Record 27 of Set 5 | pringsewu
# Processing Record 28 of Set 5 | la ronge
# Processing Record 29 of Set 5 | muhororo
# Processing Record 30 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 31 of Set 5 | fortuna
# Processing Record 32 of Set 5 | makat
# Processing Record 33 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 34 of Set 5 | padang
# Processing Record 35 of Set 5 | terre haute
# Processing Record 36 of Set 5 | riyadh
# Processing Record 37 of Set 5 | mercedes
# Processing Record 38 of Set 5 | port elizabeth
# Processing Record 39 of Set 5 | oranjemund
# Processing Record 40 of Set 5 | chokurdakh
# Processing Record 41 of Set 5 | dzaoudzi
# Processing Record 42 of Set 5 | resistencia
# Processing Record 43 of Set 5 | san rafael
# Processing Record 44 of Set 5 | kieta
# Processing Record 45 of Set 5 | muroto
# Processing Record 46 of Set 5 | port antonio
# Processing Record 47 of Set 5 | mahebourg
# Processing Record 48 of Set 5 | mao
# Processing Record 49 of Set 5 | paamiut
# Processing Record 50 of Set 5 | morant bay
# Processing Record 1 of Set 6 | hilo
# Processing Record 2 of Set 6 | turayf
# Processing Record 3 of Set 6 | goderich
# Processing Record 4 of Set 6 | sambava
# Processing Record 5 of Set 6 | kenitra
# Processing Record 6 of Set 6 | kaspiysk
# Processing Record 7 of Set 6 | mgachi
# Processing Record 8 of Set 6 | temir
# Processing Record 9 of Set 6 | stornoway
# Processing Record 10 of Set 6 | cascais
# Processing Record 11 of Set 6 | kloulklubed
# Processing Record 12 of Set 6 | karratha
# Processing Record 13 of Set 6 | trinidad
# Processing Record 14 of Set 6 | nome
# Processing Record 15 of Set 6 | dax
# Processing Record 16 of Set 6 | eregli
# Processing Record 17 of Set 6 | sverdlovskiy
# Processing Record 18 of Set 6 | bambanglipuro
# Processing Record 19 of Set 6 | cervo
# Processing Record 20 of Set 6 | la libertad
# Processing Record 21 of Set 6 | cernesti
# Processing Record 22 of Set 6 | truro
# Processing Record 23 of Set 6 | atasu
# Processing Record 24 of Set 6 | huarmey
# Processing Record 25 of Set 6 | namatanai
# Processing Record 26 of Set 6 | aqtobe
# Processing Record 27 of Set 6 | soc trang
# Processing Record 28 of Set 6 | sunland park
# Processing Record 29 of Set 6 | namwala
# Processing Record 30 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 6 | dingle
# Processing Record 32 of Set 6 | baykit
# Processing Record 33 of Set 6 | amga
# Processing Record 34 of Set 6 | fereydun kenar
# Processing Record 35 of Set 6 | geraldton
# Processing Record 36 of Set 6 | phangnga
# Processing Record 37 of Set 6 | barrhead
# Processing Record 38 of Set 6 | zelenets
# Processing Record 39 of Set 6 | brae
# Processing Record 40 of Set 6 | zhitikara
# City not found. Skipping...
# Processing Record 41 of Set 6 | xiongyue
# Processing Record 42 of Set 6 | houston
# Processing Record 43 of Set 6 | doha
# Processing Record 44 of Set 6 | sheksna
# Processing Record 45 of Set 6 | burkhala
# City not found. Skipping...
# Processing Record 46 of Set 6 | kiruna
# Processing Record 47 of Set 6 | erzin
# Processing Record 48 of Set 6 | taltal
# Processing Record 49 of Set 6 | faanui
# Processing Record 50 of Set 6 | nisia floresta
# Processing Record 1 of Set 7 | verkhniy baskunchak
# Processing Record 2 of Set 7 | abha
# Processing Record 3 of Set 7 | belyy
# Processing Record 4 of Set 7 | uromi
# Processing Record 5 of Set 7 | luderitz
# Processing Record 6 of Set 7 | lazaro cardenas
# Processing Record 7 of Set 7 | bowen
# Processing Record 8 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 7 | lufilufi
# Processing Record 10 of Set 7 | grand gaube
# Processing Record 11 of Set 7 | madang
# Processing Record 12 of Set 7 | furukawa
# Processing Record 13 of Set 7 | marshall
# Processing Record 14 of Set 7 | chumikan
# Processing Record 15 of Set 7 | kununurra
# Processing Record 16 of Set 7 | san carlos
# Processing Record 17 of Set 7 | mamallapuram
# Processing Record 18 of Set 7 | baghdad
# Processing Record 19 of Set 7 | roebourne
# Processing Record 20 of Set 7 | olafsvik
# Processing Record 21 of Set 7 | bubaque
# Processing Record 22 of Set 7 | mount gambier
# Processing Record 23 of Set 7 | bethel
# Processing Record 24 of Set 7 | angra
# City not found. Skipping...
# Processing Record 25 of Set 7 | faya
# Processing Record 26 of Set 7 | olga
# Processing Record 27 of Set 7 | la palma
# Processing Record 28 of Set 7 | norman wells
# Processing Record 29 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 30 of Set 7 | tamiahua
# Processing Record 31 of Set 7 | vila franca do campo
# Processing Record 32 of Set 7 | ilulissat
# Processing Record 33 of Set 7 | kodiak
# Processing Record 34 of Set 7 | dauphin
# Processing Record 35 of Set 7 | savalou
# Processing Record 36 of Set 7 | cayenne
# Processing Record 37 of Set 7 | pisco
# Processing Record 38 of Set 7 | beidao
# Processing Record 39 of Set 7 | le port
# Processing Record 40 of Set 7 | yicheng
# Processing Record 41 of Set 7 | hare bay
# Processing Record 42 of Set 7 | santa maria
# Processing Record 43 of Set 7 | inhambane
# Processing Record 44 of Set 7 | lokosovo
# Processing Record 45 of Set 7 | carnarvon
# Processing Record 46 of Set 7 | alice town
# Processing Record 47 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 7 | grants pass
# Processing Record 49 of Set 7 | nouadhibou
# Processing Record 50 of Set 7 | tanout
# Processing Record 1 of Set 8 | leningradskiy
# Processing Record 2 of Set 8 | komsomolskiy
# Processing Record 3 of Set 8 | sayalgudi
# City not found. Skipping...
# Processing Record 4 of Set 8 | vrangel
# Processing Record 5 of Set 8 | axim
# Processing Record 6 of Set 8 | pishin
# Processing Record 7 of Set 8 | pacific grove
# Processing Record 8 of Set 8 | honningsvag
# Processing Record 9 of Set 8 | cabedelo
# Processing Record 10 of Set 8 | henties bay
# Processing Record 11 of Set 8 | eldorado
# Processing Record 12 of Set 8 | tautira
# Processing Record 13 of Set 8 | san patricio
# Processing Record 14 of Set 8 | dipkarpaz
# City not found. Skipping...
# Processing Record 15 of Set 8 | souillac
# Processing Record 16 of Set 8 | emba
# Processing Record 17 of Set 8 | warwick
# Processing Record 18 of Set 8 | bathsheba
# Processing Record 19 of Set 8 | taoudenni
# Processing Record 20 of Set 8 | belomorsk
# Processing Record 21 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 8 | grevena
# Processing Record 23 of Set 8 | lalsk
# Processing Record 24 of Set 8 | codrington
# Processing Record 25 of Set 8 | raga
# Processing Record 26 of Set 8 | lashio
# Processing Record 27 of Set 8 | port lincoln
# Processing Record 28 of Set 8 | qaqortoq
# Processing Record 29 of Set 8 | jaisalmer
# Processing Record 30 of Set 8 | coolum beach
# Processing Record 31 of Set 8 | rundu
# Processing Record 32 of Set 8 | aberdare
# Processing Record 33 of Set 8 | najran
# Processing Record 34 of Set 8 | klyuchi
# Processing Record 35 of Set 8 | buala
# Processing Record 36 of Set 8 | jumla
# Processing Record 37 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 8 | manokwari
# Processing Record 39 of Set 8 | masuguru
# Processing Record 40 of Set 8 | malanje
# Processing Record 41 of Set 8 | mandalgovi
# Processing Record 42 of Set 8 | avera
# Processing Record 43 of Set 8 | jardim
# Processing Record 44 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 8 | sao filipe
# Processing Record 46 of Set 8 | mitsamiouli
# Processing Record 47 of Set 8 | jibuti
# Processing Record 48 of Set 8 | gejiu
# Processing Record 49 of Set 8 | san pedro
# Processing Record 50 of Set 8 | general roca
# Processing Record 1 of Set 9 | sergeyevka
# Processing Record 2 of Set 9 | george
# Processing Record 3 of Set 9 | vasto
# Processing Record 4 of Set 9 | redmond
# Processing Record 5 of Set 9 | inirida
# Processing Record 6 of Set 9 | husavik
# Processing Record 7 of Set 9 | clarence town
# Processing Record 8 of Set 9 | warrnambool
# Processing Record 9 of Set 9 | road town
# Processing Record 10 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 9 | plaster rock
# Processing Record 12 of Set 9 | mariel
# Processing Record 13 of Set 9 | cao bang
# Processing Record 14 of Set 9 | cockburn town
# Processing Record 15 of Set 9 | dudinka
# Processing Record 16 of Set 9 | ormara
# Processing Record 17 of Set 9 | sicamous
# Processing Record 18 of Set 9 | porbandar
# Processing Record 19 of Set 9 | kurumkan
# Processing Record 20 of Set 9 | makurdi
# Processing Record 21 of Set 9 | severo-yeniseyskiy
# Processing Record 22 of Set 9 | port hedland
# Processing Record 23 of Set 9 | chimbote
# Processing Record 24 of Set 9 | lorengau
# Processing Record 25 of Set 9 | kamenka
# Processing Record 26 of Set 9 | qingan
# City not found. Skipping...
# Processing Record 27 of Set 9 | puerto cabezas
# Processing Record 28 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 9 | vanimo
# Processing Record 30 of Set 9 | oktyabrskoye
# Processing Record 31 of Set 9 | richards bay
# Processing Record 32 of Set 9 | isangel
# Processing Record 33 of Set 9 | atambua
# Processing Record 34 of Set 9 | kahului
# Processing Record 35 of Set 9 | palmer
# Processing Record 36 of Set 9 | bonavista
# Processing Record 37 of Set 9 | melo
# Processing Record 38 of Set 9 | bengkulu
# Processing Record 39 of Set 9 | liverpool
# Processing Record 40 of Set 9 | anadyr
# Processing Record 41 of Set 9 | broome
# Processing Record 42 of Set 9 | cidreira
# Processing Record 43 of Set 9 | conde
# Processing Record 44 of Set 9 | egvekinot
# Processing Record 45 of Set 9 | kitimat
# Processing Record 46 of Set 9 | savannah bight
# Processing Record 47 of Set 9 | tuy hoa
# Processing Record 48 of Set 9 | portland
# Processing Record 49 of Set 9 | pechora
# Processing Record 50 of Set 9 | gasa
# Processing Record 1 of Set 10 | sabang
# Processing Record 2 of Set 10 | abu dhabi
# Processing Record 3 of Set 10 | ancud
# Processing Record 4 of Set 10 | baruun-urt
# Processing Record 5 of Set 10 | naze
# Processing Record 6 of Set 10 | clyde river
# Processing Record 7 of Set 10 | ruhengeri
# Processing Record 8 of Set 10 | beyneu
# Processing Record 9 of Set 10 | broken hill
# Processing Record 10 of Set 10 | port-gentil
# Processing Record 11 of Set 10 | wicklow
# Processing Record 12 of Set 10 | nautla
# Processing Record 13 of Set 10 | zhigansk
# Processing Record 14 of Set 10 | fort nelson
# Processing Record 15 of Set 10 | talnakh
# Processing Record 16 of Set 10 | berbera
# Processing Record 17 of Set 10 | dalvik
# Processing Record 18 of Set 10 | araouane
# Processing Record 19 of Set 10 | harnosand
# Processing Record 20 of Set 10 | acapulco
# Processing Record 21 of Set 10 | makung
# City not found. Skipping...
# Processing Record 22 of Set 10 | srednekolymsk
# Processing Record 23 of Set 10 | antalaha
# Processing Record 24 of Set 10 | burnie
# Processing Record 25 of Set 10 | whitehorse
# Processing Record 26 of Set 10 | guerrero negro
# Processing Record 27 of Set 10 | nemuro
# Processing Record 28 of Set 10 | mackay
# Processing Record 29 of Set 10 | sandwick
# Processing Record 30 of Set 10 | tottori
# Processing Record 31 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 10 | berlevag
# Processing Record 33 of Set 10 | okhotsk
# Processing Record 34 of Set 10 | sistranda
# Processing Record 35 of Set 10 | grindavik
# Processing Record 36 of Set 10 | pitimbu
# Processing Record 37 of Set 10 | saint anthony
# Processing Record 38 of Set 10 | sangar
# Processing Record 39 of Set 10 | port blair
# Processing Record 40 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 41 of Set 10 | koumac
# Processing Record 42 of Set 10 | tessalit
# Processing Record 43 of Set 10 | tarauaca
# Processing Record 44 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 45 of Set 10 | am timan
# Processing Record 46 of Set 10 | nabire
# Processing Record 47 of Set 10 | porto santo
# Processing Record 48 of Set 10 | nyakabindi
# Processing Record 49 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 50 of Set 10 | nanortalik
# Processing Record 1 of Set 11 | opelousas
# Processing Record 2 of Set 11 | kashipur
# Processing Record 3 of Set 11 | georgetown
# Processing Record 4 of Set 11 | wenceslau braz
# Processing Record 5 of Set 11 | americus
# Processing Record 6 of Set 11 | san isidro
# Processing Record 7 of Set 11 | vanavara
# Processing Record 8 of Set 11 | poum
# Processing Record 9 of Set 11 | zhuhai
# Processing Record 10 of Set 11 | alice springs
# Processing Record 11 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 11 | norsup
# Processing Record 13 of Set 11 | roanoke rapids
# Processing Record 14 of Set 11 | guicheng
# City not found. Skipping...
# Processing Record 15 of Set 11 | teguise
# Processing Record 16 of Set 11 | mahon
# Processing Record 17 of Set 11 | nador
# Processing Record 18 of Set 11 | villeneuve-sur-lot
# Processing Record 19 of Set 11 | warmbad
# Processing Record 20 of Set 11 | manzhouli
# Processing Record 21 of Set 11 | havre-saint-pierre
# Processing Record 22 of Set 11 | beinamar
# Processing Record 23 of Set 11 | belmonte
# Processing Record 24 of Set 11 | sinnamary
# Processing Record 25 of Set 11 | balkhash
# Processing Record 26 of Set 11 | havoysund
# Processing Record 27 of Set 11 | aberdeen
# Processing Record 28 of Set 11 | chapais
# Processing Record 29 of Set 11 | sakaiminato
# Processing Record 30 of Set 11 | canico
# Processing Record 31 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 32 of Set 11 | lebu
# Processing Record 33 of Set 11 | caravelas
# Processing Record 34 of Set 11 | prado
# Processing Record 35 of Set 11 | waingapu
# Processing Record 36 of Set 11 | balta
# Processing Record 37 of Set 11 | sikonge
# Processing Record 38 of Set 11 | mount isa
# Processing Record 39 of Set 11 | zabol
# Processing Record 40 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 41 of Set 11 | ayna
# Processing Record 42 of Set 11 | miri
# Processing Record 43 of Set 11 | kysyl-syr
# Processing Record 44 of Set 11 | yeppoon
# Processing Record 45 of Set 11 | port macquarie
# Processing Record 46 of Set 11 | ixtapa
# Processing Record 47 of Set 11 | khorixas
# Processing Record 48 of Set 11 | kaitong
# Processing Record 49 of Set 11 | parangan
# Processing Record 50 of Set 11 | ambilobe
# Processing Record 1 of Set 12 | ortona
# Processing Record 2 of Set 12 | byron bay
# Processing Record 3 of Set 12 | gravdal
# Processing Record 4 of Set 12 | kavaratti
# Processing Record 5 of Set 12 | seydi
# Processing Record 6 of Set 12 | biak
# Processing Record 7 of Set 12 | tutubigan
# Processing Record 8 of Set 12 | taree
# Processing Record 9 of Set 12 | veles
# Processing Record 10 of Set 12 | fuerte olimpo
# Processing Record 11 of Set 12 | dasoguz
# Processing Record 12 of Set 12 | opuwo
# Processing Record 13 of Set 12 | ossora
# Processing Record 14 of Set 12 | flin flon
# Processing Record 15 of Set 12 | champerico
# Processing Record 16 of Set 12 | atar
# Processing Record 17 of Set 12 | mandiana
# Processing Record 18 of Set 12 | calatrava
# Processing Record 19 of Set 12 | la primavera
# Processing Record 20 of Set 12 | dabakala
# Processing Record 21 of Set 12 | saint-pierre
# Processing Record 22 of Set 12 | vigrestad
# Processing Record 23 of Set 12 | lakes entrance
# Processing Record 24 of Set 12 | scottsbluff
# Processing Record 25 of Set 12 | progreso
# Processing Record 26 of Set 12 | blackmans
# City not found. Skipping...
# Processing Record 27 of Set 12 | kumi
# Processing Record 28 of Set 12 | shellbrook
# Processing Record 29 of Set 12 | ballina
# Processing Record 30 of Set 12 | krasnomayskiy
# Processing Record 31 of Set 12 | quatre cocos
# Processing Record 32 of Set 12 | igarka
# Processing Record 33 of Set 12 | longyearbyen
# Processing Record 34 of Set 12 | grand forks
# Processing Record 35 of Set 12 | benguela
# Processing Record 36 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 37 of Set 12 | negombo
# Processing Record 38 of Set 12 | mochudi
# Processing Record 39 of Set 12 | narsaq
# Processing Record 40 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 41 of Set 12 | boatlaname
# City not found. Skipping...
# Processing Record 42 of Set 12 | mjolby
# Processing Record 43 of Set 12 | santa fe
# Processing Record 44 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 46 of Set 12 | araripina
# Processing Record 47 of Set 12 | imeni poliny osipenko
# Processing Record 48 of Set 12 | alghero
# Processing Record 49 of Set 12 | skala
# Processing Record 50 of Set 12 | maniitsoq
# Processing Record 1 of Set 13 | kropotkin
# Processing Record 2 of Set 13 | chingirlau
# Processing Record 3 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 4 of Set 13 | challapata
# Processing Record 5 of Set 13 | marawi
# Processing Record 6 of Set 13 | borogontsy
# Processing Record 7 of Set 13 | okahandja
# Processing Record 8 of Set 13 | bereznik
# Processing Record 9 of Set 13 | sisimiut
# Processing Record 10 of Set 13 | waverly
# Processing Record 11 of Set 13 | thunder bay
# Processing Record 12 of Set 13 | concordia
# Processing Record 13 of Set 13 | pedernales
# Processing Record 14 of Set 13 | memaliaj
# Processing Record 15 of Set 13 | banamba
# Processing Record 16 of Set 13 | san vicente
# Processing Record 17 of Set 13 | carupano
# Processing Record 18 of Set 13 | orcopampa
# Processing Record 19 of Set 13 | chengde
# Processing Record 20 of Set 13 | bilisht
# Processing Record 21 of Set 13 | almetyevsk
# Processing Record 22 of Set 13 | drumheller
# Processing Record 23 of Set 13 | digboi
# Processing Record 24 of Set 13 | coleraine
# Processing Record 25 of Set 13 | galeana
# Processing Record 26 of Set 13 | pangnirtung
# Processing Record 27 of Set 13 | galle
# Processing Record 28 of Set 13 | dhidhdhoo
# Processing Record 29 of Set 13 | jalu
# Processing Record 30 of Set 13 | novikovo
# Processing Record 31 of Set 13 | maidstone
# Processing Record 32 of Set 13 | churapcha
# Processing Record 33 of Set 13 | chardara
# Processing Record 34 of Set 13 | angostura
# Processing Record 35 of Set 13 | tabas
# Processing Record 36 of Set 13 | raurkela
# City not found. Skipping...
# Processing Record 37 of Set 13 | murray bridge
# Processing Record 38 of Set 13 | fountain
# Processing Record 39 of Set 13 | tigzirt
# Processing Record 40 of Set 13 | aksha
# Processing Record 41 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 13 | batemans bay
# Processing Record 43 of Set 13 | atlantic city
# Processing Record 44 of Set 13 | baijiantan
# Processing Record 45 of Set 13 | roma
# Processing Record 46 of Set 13 | lavrentiya
# Processing Record 47 of Set 13 | isla vista
# Processing Record 48 of Set 13 | aquiraz
# Processing Record 49 of Set 13 | nyurba
# Processing Record 50 of Set 13 | xingcheng
# Processing Record 1 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 14 | bilibino
# Processing Record 3 of Set 14 | guangshui
# Processing Record 4 of Set 14 | ulety
# Processing Record 5 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 6 of Set 14 | tocopilla
# Processing Record 7 of Set 14 | drayton valley
# Processing Record 8 of Set 14 | mariakani
# Processing Record 9 of Set 14 | erenhot
# Processing Record 10 of Set 14 | port hardy
# Processing Record 11 of Set 14 | merauke
# Processing Record 12 of Set 14 | verkhnevilyuysk
# Processing Record 13 of Set 14 | constanza
# Processing Record 14 of Set 14 | boralday
# Processing Record 15 of Set 14 | presidencia roque saenz pena
# Processing Record 16 of Set 14 | ninotsminda
# Processing Record 17 of Set 14 | barra do garcas
# Processing Record 18 of Set 14 | ust-ishim
# Processing Record 19 of Set 14 | prince rupert
# Processing Record 20 of Set 14 | pochutla
# Processing Record 21 of Set 14 | dwarka
# Processing Record 22 of Set 14 | moskovskiy
# Processing Record 23 of Set 14 | ugoofaaru
# Processing Record 24 of Set 14 | zhezkazgan
# Processing Record 25 of Set 14 | kiama
# Processing Record 26 of Set 14 | shatrovo
# Processing Record 27 of Set 14 | strand
# Processing Record 28 of Set 14 | port augusta
# Processing Record 29 of Set 14 | pevek
# Processing Record 30 of Set 14 | luganville
# Processing Record 31 of Set 14 | san policarpo
# Processing Record 32 of Set 14 | izhma
# Processing Record 33 of Set 14 | colares
# Processing Record 34 of Set 14 | hofn
# Processing Record 35 of Set 14 | soeng sang
# Processing Record 36 of Set 14 | san quintin
# Processing Record 37 of Set 14 | aklera
# Processing Record 38 of Set 14 | aracuai
# Processing Record 39 of Set 14 | pilao arcado
# City not found. Skipping...
# Processing Record 40 of Set 14 | geghamasar
# Processing Record 41 of Set 14 | sorland
# Processing Record 42 of Set 14 | cuamba
# Processing Record 43 of Set 14 | teya
# Processing Record 44 of Set 14 | hualmay
# Processing Record 45 of Set 14 | nampula
# Processing Record 46 of Set 14 | deep river
# Processing Record 47 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 14 | gold coast
# Processing Record 49 of Set 14 | da nang
# Processing Record 50 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 15 | margate
# Processing Record 2 of Set 15 | evensk
# Processing Record 3 of Set 15 | armidale
# Processing Record 4 of Set 15 | casablanca
# Processing Record 5 of Set 15 | tura
# Processing Record 6 of Set 15 | puerto escondido
# Processing Record 7 of Set 15 | tarbert
# Processing Record 8 of Set 15 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 9 of Set 15 | palatka
# Processing Record 10 of Set 15 | altay
# Processing Record 11 of Set 15 | jinxiang
# Processing Record 12 of Set 15 | upington
# Processing Record 13 of Set 15 | lakewood
# Processing Record 14 of Set 15 | saldanha
# Processing Record 15 of Set 15 | esso
# Processing Record 16 of Set 15 | svetlogorsk
# Processing Record 17 of Set 15 | salacgriva
# Processing Record 18 of Set 15 | flinders
# Processing Record 19 of Set 15 | kajaani
# Processing Record 20 of Set 15 | kaseda
# Processing Record 21 of Set 15 | ferkessedougou
# Processing Record 22 of Set 15 | knysna
# Processing Record 23 of Set 15 | great bend
# Processing Record 24 of Set 15 | savonlinna
# Processing Record 25 of Set 15 | yenagoa
# Processing Record 26 of Set 15 | miraflores
# Processing Record 27 of Set 15 | oyama
# Processing Record 28 of Set 15 | zachary
# Processing Record 29 of Set 15 | tiznit
# Processing Record 30 of Set 15 | tari
# Processing Record 31 of Set 15 | svetlyy
# Processing Record 32 of Set 15 | heias
# City not found. Skipping...
# Processing Record 33 of Set 15 | shubarshi
# Processing Record 34 of Set 15 | verkhnyaya inta
# Processing Record 35 of Set 15 | mabaruma
# Processing Record 36 of Set 15 | ponta delgada
# Processing Record 37 of Set 15 | dharchula
# Processing Record 38 of Set 15 | marsh harbour
# Processing Record 39 of Set 15 | milkovo
# Processing Record 40 of Set 15 | miranda de ebro
# Processing Record 41 of Set 15 | iquitos
# Processing Record 42 of Set 15 | wanning
# Processing Record 43 of Set 15 | campbell river
# Processing Record 44 of Set 15 | bac lieu
# Processing Record 45 of Set 15 | grand bank
# Processing Record 46 of Set 15 | druzhba
# Processing Record 47 of Set 15 | ginir
# Processing Record 48 of Set 15 | agadez
# Processing Record 49 of Set 15 | launceston
# Processing Record 50 of Set 15 | kungalv
# Processing Record 1 of Set 16 | ocnita
# Processing Record 2 of Set 16 | hervey bay
# Processing Record 3 of Set 16 | maltahohe
# Processing Record 4 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 16 | tamandare
# Processing Record 6 of Set 16 | patacamaya
# Processing Record 7 of Set 16 | yakeshi
# Processing Record 8 of Set 16 | gbadolite
# Processing Record 9 of Set 16 | aripuana
# Processing Record 10 of Set 16 | talara
# Processing Record 11 of Set 16 | birobidzhan
# Processing Record 12 of Set 16 | awbari
# Processing Record 13 of Set 16 | hambantota
# Processing Record 14 of Set 16 | fairbanks
# Processing Record 15 of Set 16 | yendi
# Processing Record 16 of Set 16 | safford
# Processing Record 17 of Set 16 | qui nhon
# Processing Record 18 of Set 16 | luwuk
# Processing Record 19 of Set 16 | thinadhoo
# Processing Record 20 of Set 16 | vao
# Processing Record 21 of Set 16 | binzhou
# Processing Record 22 of Set 16 | bay roberts
# Processing Record 23 of Set 16 | bartlesville
# Processing Record 24 of Set 16 | talalayivka
# Processing Record 25 of Set 16 | ulaangom
# Processing Record 26 of Set 16 | otane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0   Arraial Do Cabo      BR -22.9661  -42.0278     69.80        87
# 1           Mataura      NZ -46.1927  168.8643     44.47        91
# 2  Praia Da Vitoria      PT  38.7333  -27.0667     70.75        94
# 3            Ulcinj      ME  41.9294   19.2244     76.50        51
# 4      Punta Arenas      CL -53.1500  -70.9167     32.11        86
# 5           Ushuaia      AR -54.8000  -68.3000     31.66        93
# 6             Mecca      SA  21.4267   39.8261     83.37        59
# 7             Alofi      NU -19.0595 -169.9187     80.49        65
# 8      Puerto Ayora      EC  -0.7393  -90.3518     67.55        98
# 9          Kedrovyy      RU  56.1667   91.8167     64.87        65
#
#    Cloudiness  Wind Speed Current Description
# 0           1       16.11           clear sky
# 1          96        3.31     overcast clouds
# 2           0        2.35           clear sky
# 3           0        3.80           clear sky
# 4          20       16.11          few clouds
# 5          75       28.77                snow
# 6           5        4.83           clear sky
# 7          40       11.50    scattered clouds
# 8          47        1.99    scattered clouds
# 9         100        8.21          light rain

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
